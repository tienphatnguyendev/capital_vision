# %%
len(active_symbols)

# %% [markdown]
# # Check existing of dict elem safely

# %%
my_dict = {'a': 1, 'b': 2}

value_a = my_dict.get('a', None)  # Returns 1

if res := my_dict.get('c', None):  # Returns None because 'c' is not in the dictionary 
    print('Value of c:', res)
else:
    print(f'res is {res}')
